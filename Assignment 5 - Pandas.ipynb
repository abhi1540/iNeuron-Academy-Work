# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv')
df.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
# Wrong Question

# %% [markdown]
# 2. Show the distribution of male and female

# %%
df.sex.value_counts()
df.sex.value_counts().plot(kind='pie',  subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f37adacdda0>],
#       dtype=object)

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
df.name.value_counts()[:5]
# Out:
# Jessie       258
# Leslie       247
# Guadalupe    244
# Jean         244
# Lee          240
# Name: name, dtype: int64

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
# Wrong Question

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
# Wrong Question

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
# https://python-graph-gallery.com/11-grouped-barplot/

# libraries
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
 
# set width of bar
barWidth = 0.25
 
# set height of bar
max = [39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25]
min = [21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]

 
# Set position of bar on X axis
r1 = np.arange(len(max))
r2 = [x + barWidth for x in r1]

# Make the plot
plt.bar(r1, max, color='#7f6d5f', width=barWidth, edgecolor='white', label='max')
plt.bar(r2, min, color='#557f2d', width=barWidth, edgecolor='white', label='min')

 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(max))], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov','Dec'])
 

# Create legend & Show graphic
plt.legend()
plt.show()
