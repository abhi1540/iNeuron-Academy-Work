# %% [markdown]
# 1. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
def func(start=2000, end=3201):
    for i in range(start,end):
        if i % 7 == 0 and i % 5 != 0:
            print(i, sep='', end=',')
            
func(2000,3201)

# %% [markdown]
# 2. Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name

# %%
first_nm = input("Please enter first name:")
last_nm = input("Please enter last name:")

def func(arg1, arg2):
    return (arg1[::-1] + " " + arg2[::-1])

func(first_nm, last_nm)

# %% [markdown]
# 3.Write a Python program to find the volume of a sphere with diameter 12 cm.
#
# Formula: V=4/3 * π * r 3

# %%
import math
def volcalc(dia):
    
    return (4/3)*math.pi*(dia/2)*3

volcalc(12)

# %% [markdown]
# 4.Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
seq = input("Enter comma-separated numbers:")
def func(arg):
    return [i for i in arg.split(",")]

func(seq)

# %% [raw]
# 5. Create the below pattern using nested for loop in Python.
#
#
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
def func(arg):
    for i in range(1,arg):
        for j in range(i):
            print("*", end=" ")
        print(end="\n")
    for k in range(arg-2,0,-1):
        for l in range(k):
            print("*", end=" ")
        print(end="\n")
        
func(6)

# %% [markdown]
# 6. Write a Python program to reverse a word after accepting the input from the user.
#
# Sample Output:
#
# Input word: iNeuron
#
# Output: norueNi

# %%
seq = input("Enter the word:")
def func(arg):
    return arg[::-1]

func(seq)

# %% [markdown]
# 7. Write a Python Program to print the given string in the format specified in the ​sample output.
#  WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
#
# Sample Output:
#
# WE, THE PEOPLE OF INDIA,   having solemnly resolved to constitute India into a SOVEREIGN, !  SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC    and to secure to all its citizens

# %%
strng = input("Please Enter the string:")
def func(arg):
    strs = arg.split("SOVEREIGN,")
    return "{}{}{}{}".format(strs[0], "SOVEREIGN,", "!" , strs[1])

func(strng)

# %% [markdown]
# Note : - NOTE:​ ​The​ ​solution​ ​shared​ ​through​ ​Github​ ​should​ ​contain​ ​the​ ​source code​ ​used​ ​ and​  ​the​ ​output
