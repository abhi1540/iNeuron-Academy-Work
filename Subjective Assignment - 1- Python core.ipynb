# %% [markdown]
# Q1. Write a Python program to get the string from the given string where
# all the occurrence of its first char has been changed to '$,' except first
# char itself?
#
#     Sample String: 'prospect'
#     Expected Result : 'pros$ect'

# %%
str1 = input("Please enter the string:")

def func(arg):
    dict1 = {}
    str2 = ''
    for i in arg:
        if i in dict1:
            dict1[i] += 1
            str2 += '$'
        else:
            dict1[i] = 1
            str2 += i
    return str2

func(str1)

# %% [markdown]
# Q2. Write a Python program to get the single string from the two given
# strings, and separated by the space and swap the first two characters of
# each string?
#
#     Sample String : 'abc', 'xyz'.
#     Expected Result: 'xyc abz'

# %%
def func(arg1="abc", arg2="xyz"):
    result = arg1[0:2] + arg2[2:3] + " " + arg2[0:2] + arg1[2:3]
    
    return result

func("abc", "xyz")

# %% [markdown]
# Q3. Write the Python program to add 'ing' at the end of the given string
# (length of the string should be at least 3). If given string already ends
# with 'ing,' then add 'ly' instead. If string length of the given string is less
# than 3, leave it unchanged?
#
#
#     Sample string: ' abc '
#     Expected result: ' abcing '
#     Sample string: ' string '
#     Expected result: ' stringly '

# %%
def func(arg):
    
    if len(arg) < 3:
        return arg
    elif arg[-3:] == "ing":
        return arg[:-3] + "ly"
    else:
        return arg + "ing"
    
func("string")

# %% [markdown]
# Q4. Write the Python program to find the first appearance of the
# substring 'not' and 'poor' from the given string, if 'not' follows the 'poor',
# replace the whole 'not'...' poor' substring with 'good'.Return the resulting
# string.
#
#     Sample string: 'The lyrics are not that poor!'
#     'The lyrics are poor!'
#     Expected Result: 'The lyrics are good!'
#     'The lyrics are poor!'

# %%
import re

def func(arg):
    
    if arg.find(r"not.*poor"):
        return re.sub('not.*poor', 'good', arg)
    else:
        return arg
    
print(func('The lyrics are not that poor!'))
print(func('The lyrics are poor!'))

# %% [markdown]
# Q5. Write the Python program to remove the characters which have odd
# index values of a given string.

# %%
def func(arg):
    
    return arg[::2]

func("hello")

# %% [markdown]
# Q6. Write the python program to print the following floating numbers up
# to 2 decimal places?

# %%
def func(arg):
    
    return round(arg,2)

func(12.3333)

# %% [markdown]
# Q7. Write the Python program to format a number with a percentage?

# %%
def func(arg):
    
    return "%.2f" % round(arg,2)

func(12.3333)

# %% [markdown]
# Q8. Write the Python program to count occurrences of a substring in a
# String?

# %%
def func(arg1, arg2):
    
    return arg1.count(arg2)

func("tell me something which is not related to me", "me")

# %% [markdown]
# Q9. Write the Python program to count repeated characters in a string.
#
#     Sample string: ' thequickbrownjumpsoverthelazydog '
#
#     Expected output:
#     o 3
#     e 3
#     u 2
#     h 2
#     r 2
#     t 2

# %%
def func(arg):
    
    dict1 = {}
    for i in arg:
        if i in dict1:
            dict1[i] += 1
        else:
            dict1[i] = 1
            
    for i,j in dict1.items():
        print(i,j)
        
func("thequickbrownjumpsoverthelazydog")

# %% [markdown]
# Q10. Write the Python program to print the square and cube symbol in
# the area of a rectangle and volume of a cylinder?
#
#     Sample outputThe area of the rectangle is 1256.66cm2
#     The volume of the cylinder is 1254.725cm3

# %%
import math
def rect(height, width):
    
    return "The area of the rectangle is {}cm2".format(height * width)

def cylin(radius, height):
    return "The volume of the cylinder is {}cm2".format(math.pi*(radius^2)*height)


print(rect(12,10))
print(cylin(12,10))

# %% [markdown]
# Q11. Write the Python program to check if a string contains all letters of
# the alphabet?

# %%
def func(arg):
    
    flag = False
    if re.match(r'^[a-zA-Z]*$', arg):
        flag = True
    return flag


print(func("hello"))
print(func("hell111"))

# %% [markdown]
# Q12. Write the Python program to find the second most repeated word
# in a given string?

# %%
from collections import Counter
def func(*arg):
    dict1 = Counter(arg)
    value = sorted(dict1.items(),key=lambda item: item[1], reverse=True)
    return value[1][0]

func("hello", "hi", "hi", "hey",  "hi", "hello")

# %% [markdown]
# Q13. Write the Python program to find the minimum window in the given
# string, which will contains all the characters of another given
# strings?
#
#     Example 1
#     Input : string1 = " PRWSOERIUSFK "
#     string2 = " OSU "
#     Output: Minimum window is "OERIUS"

# %%
str1 = "PRWSOERIUSFK"
str2 = "OSU"
dict1 = {}
for i in str2:
    if i not in dict1:
        dict1[i] = 1
    else:
        pass
    
dict2 = {}
for i in str1:
    if i in dict1 and dict2:
        dict2[i] = 1
    else:
        dict2[i] = 0
        

def func(str1, str2, dict1, dict2):
    
    left,right,i,j = 0,0,0,0
    missing_count = len(dict1)
    while right < len(str1):
        if dict2[str1[right]] > 0:
            missing_count -= 1
            dict2[str1[right]] -= 1
        right += 1

        while missing_count == 0:
            if j == 0 or right - left < i - j:
                i,j = right, left
            if str1[left] in dict1:
                dict2[str1[left]] += 1
            if dict2[str1[left]] > 0:
                missing_count += 1
            left += 1
    return str1[j:i]
            

func(str1, str2, dict1, dict2)

# %% [markdown]
# Q14. Write the Python program to count number of substrings from a
# given string of lowercase alphabets with exactly k distinct (given)
# characters?
#
#     Input a string (lowercase alphabets): wolf
#     Input k: 4
#     Number of substrings with exactly 4 distinct characters: 1

# %%
list1 = []
str1 = "wolf"


def func(list1, str1, k):
    
    right, left = 0, 0
    str1 = str1 + " "
    dict1 = {}
    while right < len(str1):

        if str1[right] in dict1 or len(dict1) == k:
            list1.append(str1[left:right])
            dict1 = {}
            left += 1
            right -= 1

        else:
            dict1[str1[right]] = 1
            right += 1
    return len(list1)

func(list1, str1, 4)
# Out:
# {'w': 1}
# {'w': 1, 'o': 1}
# {'w': 1, 'o': 1, 'l': 1}
# {'w': 1, 'o': 1, 'l': 1, 'f': 1}
# 0 4
# {'w': 1, 'o': 1, 'l': 1, 'f': 1}
# {'f': 1}
# {'f': 1, ' ': 1}
# ['wolf']

# %% [markdown]
# Q15. Write the Python program to count number of substrings with same
# first and last characters of the given string?
#
#     Input a string: abcd
#     4

# %%
def func(arg):
    
    count = 0
    for i in range(len(arg)):
        for j in range(i,len(arg)):
            if arg[i] == arg[j]:
                count += 1
                
    return count


func("abcd")

# %% [markdown]
# ## Great Job!
